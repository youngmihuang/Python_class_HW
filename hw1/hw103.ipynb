# %%
#hw3
# coding=utf-8
'''
將 1 到 100 印出，但是碰到 3 的倍數的時候改為輸出 "Bingo!"，碰到 5 的倍數的時候改為輸出 "Awesome!"，如果同時是 3 跟 5 的公倍數（15 的倍數），則輸出 "Gotcha!"
Author: Youngmi
'''

def Result(x):
    for i in x:
        if i % 3 == 0 and i % 5 ==0:
            print "Gotcha!"
            
        elif i%3 == 0:
            print "Bingo!"
            
        elif i%5 == 0:
            print "Awesome!"
            
        else:
            print i

print Result(range(1,101,1)) #包前不包後
# Out:
# 1
# 2
# Bingo!
# 4
# Awesome!
# Bingo!
# 7
# 8
# Bingo!
# Awesome!
# 11
# Bingo!
# 13
# 14
# Gotcha!
# 16
# 17
# Bingo!
# 19
# Awesome!
# Bingo!
# 22
# 23
# Bingo!
# Awesome!
# 26
# Bingo!
# 28
# 29
# Gotcha!
# 31
# 32
# Bingo!
# 34
# Awesome!
# Bingo!
# 37
# 38
# Bingo!
# Awesome!
# 41
# Bingo!
# 43
# 44
# Gotcha!
# 46
# 47
# Bingo!
# 49
# Awesome!
# Bingo!
# 52
# 53
# Bingo!
# Awesome!
# 56
# Bingo!
# 58
# 59
# Gotcha!
# 61
# 62
# Bingo!
# 64
# Awesome!
# Bingo!
# 67
# 68
# Bingo!
# Awesome!
# 71
# Bingo!
# 73
# 74
# Gotcha!
# 76
# 77
# Bingo!
# 79
# Awesome!
# Bingo!
# 82
# 83
# Bingo!
# Awesome!
# 86
# Bingo!
# 88
# 89
# Gotcha!
# 91
# 92
# Bingo!
# 94
# Awesome!
# Bingo!
# 97
# 98
# Bingo!
# Awesome!
# None
